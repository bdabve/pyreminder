# %%
import pandas as pd

data = pd.read_csv('/home/dabve/desktop/Schools.csv')
print(data)
# Out:
#                 Keyword                                  Location  \
# Schools       Hyderabad  Orchids The International School - Kapra
# Schools       Hyderabad     Telangana Minority Residential School
# Schools       Hyderabad                     Daffodils High School
# Schools       Hyderabad                        Loyola High School
# Schools       Hyderabad   Vidyaranya High School for Boys & Girls
# ...                 ...                                       ...
# Play Schools  Hyderabad                             Spring Valley
# Play Schools  Hyderabad                        Kids Garden School
# Play Schools  Hyderabad               LEARNING BLOCKS PLAY SCHOOL
# Play Schools  Hyderabad     Chuckles Playschool Childcare Alkapur
# Play Schools  Hyderabad                   Kinder world the school
#
#              Company name                                           Category  \
# Schools               NaN  /aclk?sa=l&ai=DChcSEwjdvrzZta35AhVRppYKHbA_AJw...
# ...
